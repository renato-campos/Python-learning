# %% [markdown]
# #### Importando a biblioteca

# %%
from pathlib import Path
import shutil

# %%
# retorna o caminho relativo atual, ou seja, '.'
caminho = Path()
print(caminho)
# Out:
# .

# %% [markdown]
# embora o caminho esteja numa forma usada por sistemas UNIX >>> Posix, a biblioteca entende qual sistema está em uso e converte para formato necessário, no caso, WindowsPath

# %%
# retorna o caminho absoluto atual
print(caminho.absolute())
# Out:
# d:\Projetos\Python-learning

# %%
# algumas curiosidades
print(Path() == Path().absolute())
print(Path() == Path('.'))
print(Path() / 'batatas' == Path().absolute() / 'batatas')
print(Path('a') == Path('a'))
print(Path('a') == Path('A'))
print(Path('a') == Path('b'))
print(Path('a') > Path('b'))
# Out:
# False
# True
# False
# True
# True
# False
# False

# %%
# torna o caminho informado um objeto manipulável, mas ainda pode ser fictício
caminho = Path('C:/Users/Renato/Desktop/Mensagens')

# %%
# verifica se o caminho realmente existe
print(caminho.exists())
# Out:
# True

# %%
# retorna o nome do diretório/arquivo atual
caminho.name
# Out:
# 'Mensagens'

# %%
# define o caminho e arquivo e depois cria
p = Path()/"pasta_0"
p.mkdir()
# %ls
# Out:
#  O volume na unidade D � Backup
#  O N�mero de S�rie do Volume � B2D4-15A0
#
#  Pasta de d:\Projetos\Python-learning
#
# 17/12/2023  15:59    <DIR>          .
# 17/12/2023  09:29    <DIR>          ..
# 17/12/2023  09:27    <DIR>          .idea
# 17/12/2023  15:56            10.588 aprendendo_pathlib.ipynb
# 17/12/2023  09:27    <DIR>          cev-mundo1
# 17/12/2023  09:27    <DIR>          cev-mundo2
# 17/12/2023  09:27    <DIR>          cisco
# 17/12/2023  09:27    <DIR>          fatec-algoritmos
# 17/12/2023  15:59    <DIR>          pasta_0
# 17/12/2023  15:45    <DIR>          teste.txt
#                1 arquivo(s)         10.588 bytes
#                9 pasta(s)   693.637.414.912 bytes dispon�veis

# %%
p.rmdir()
# %ls
# Out:
#  O volume na unidade D � Backup
#  O N�mero de S�rie do Volume � B2D4-15A0
#
#  Pasta de d:\Projetos\Python-learning
#
# 17/12/2023  15:59    <DIR>          .
# 17/12/2023  09:29    <DIR>          ..
# 17/12/2023  09:27    <DIR>          .idea
# 17/12/2023  15:59             9.191 aprendendo_pathlib.ipynb
# 17/12/2023  09:27    <DIR>          cev-mundo1
# 17/12/2023  09:27    <DIR>          cev-mundo2
# 17/12/2023  09:27    <DIR>          cisco
# 17/12/2023  09:27    <DIR>          fatec-algoritmos
# 17/12/2023  15:45    <DIR>          teste.txt
#                1 arquivo(s)          9.191 bytes
#                8 pasta(s)   693.637.414.912 bytes dispon�veis

# %%
# outro modo de definir caminho e arquivo a criar
p = Path("teste.txt")
p.touch()
# %ls
# Out:
#  O volume na unidade D � Backup
#  O N�mero de S�rie do Volume � B2D4-15A0
#
#  Pasta de d:\Projetos\Python-learning
#
# 17/12/2023  16:00    <DIR>          .
# 17/12/2023  09:29    <DIR>          ..
# 17/12/2023  09:27    <DIR>          .idea
# 17/12/2023  15:59             9.953 aprendendo_pathlib.ipynb
# 17/12/2023  09:27    <DIR>          cev-mundo1
# 17/12/2023  09:27    <DIR>          cev-mundo2
# 17/12/2023  09:27    <DIR>          cisco
# 17/12/2023  09:27    <DIR>          fatec-algoritmos
# 17/12/2023  16:00                 0 teste2.txt
#                2 arquivo(s)          9.953 bytes
#                7 pasta(s)   693.637.414.912 bytes dispon�veis

# %%
# apaga o arquivo do caminho definido
p.unlink()
# %ls
# Out:
#  O volume na unidade D � Backup
#  O N�mero de S�rie do Volume � B2D4-15A0
#
#  Pasta de d:\Projetos\Python-learning
#
# 17/12/2023  16:00    <DIR>          .
# 17/12/2023  09:29    <DIR>          ..
# 17/12/2023  09:27    <DIR>          .idea
# 17/12/2023  16:00             9.903 aprendendo_pathlib.ipynb
# 17/12/2023  09:27    <DIR>          cev-mundo1
# 17/12/2023  09:27    <DIR>          cev-mundo2
# 17/12/2023  09:27    <DIR>          cisco
# 17/12/2023  09:27    <DIR>          fatec-algoritmos
#                1 arquivo(s)          9.903 bytes
#                7 pasta(s)   693.637.414.912 bytes dispon�veis

# %%
# criar a pasta
p = Path() / 'pasta_0'
p.mkdir()

# %%
# criar o arquivo
p = p / 'teste.txt'
p.touch()

# %%
# apagando o arquivo
p.unlink()

# %%
# apagando o diretório quando vazio
p = Path()/'pasta_0'
p.rmdir()

# %%
# criar pasta, arquivo e renomeando
p = Path('pasta_0')
p.mkdir()
p = p / 'teste.txt'
p.touch()
p.rename('pasta_0/batatas.txt')
# Out:
# WindowsPath('pasta_0/batatas.txt')

# %%
# retorna o caminho do diretório pai, o mesmo que '..' ou '../..'
print(caminho)
print(caminho.parent)
print(caminho.parent.parent)
# Out:
# C:\Users\Renato\Desktop\Mensagens
# C:\Users\Renato\Desktop
# C:\Users\Renato
# [WindowsPath('C:/Users/Renato/Desktop'), WindowsPath('C:/Users/Renato'), WindowsPath('C:/Users'), WindowsPath('C:/')]

# %%
list(caminho.parents)
# Out:
# [WindowsPath('C:/Users/Renato/Desktop'),
#  WindowsPath('C:/Users/Renato'),
#  WindowsPath('C:/Users'),
#  WindowsPath('C:/')]

# %%
caminho.parts
# Out:
# ('C:\\', 'Users', 'Renato', 'Desktop', 'Mensagens')

# %%
list(p.parents)
# Out:
# [WindowsPath('.')]

# %%
list(p.absolute().parents)
# Out:
# [WindowsPath('d:/Projetos/Python-learning'),
#  WindowsPath('d:/Projetos'),
#  WindowsPath('d:/')]

# %%
p.parts
# Out:
# ('teste.txt',)

# %%
p.absolute().parts
# Out:
# ('d:\\', 'Projetos', 'Python-learning', 'teste.txt')

# %% [markdown]
# Exercício 1: Listar a **pasta_0**, que está dentro da pasta **files**, caso existam arquivos **.txt** dentro da **pasta_0**, pintar o conteúdo dos arquivos.

# %%
from pathlib import Path

# %%
caminho = Path()/'files'
caminho.mkdir()

# %%
caminho = caminho / 'pasta_0'
caminho.mkdir()

# %%
for i in range(10):
    nome = caminho / f'arquivo{i}.txt'
    nome.touch()

# %%
lista = list(caminho.glob('*.txt'))

# %%
# abrindo os arquivos via 'with' e escrevendo
for arq in lista:
    with open(arq, 'w') as f:
        f.write(f'{arq}')

# %%
# abrindo e lendo os arquivos agora via 'glob' com seu iterador de resposta
for f in Path('files/pasta_0').glob('*.txt'):
    print(f.read_text())
# Out:
# files\pasta_0\arquivo0.txt
# files\pasta_0\arquivo1.txt
# files\pasta_0\arquivo2.txt
# files\pasta_0\arquivo3.txt
# files\pasta_0\arquivo4.txt
# files\pasta_0\arquivo5.txt
# files\pasta_0\arquivo6.txt
# files\pasta_0\arquivo7.txt
# files\pasta_0\arquivo8.txt
# files\pasta_0\arquivo9.txt

# %% [markdown]
# Exercício 2: listar a pasta **pasta_0**, que está dentro da pasta **files**, caso existam arquivos **.txt** dentro da **pasta_0**, crie uma nova pasta chamada **desafio_2** e copie os arquivos para essa pasta.

# %%
caminho = Path() / 'files'/'desafio_2'
caminho.mkdir()
for f in Path('files/pasta_0').glob('*.txt'):
    #shutil.move(f, caminho)
    shutil.copy(f, caminho)
